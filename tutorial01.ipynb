# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahemAmar/Introduction-to-Cloud-Computing-/blob/main/tutorial01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# sample_data/

# %%
import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y,)

plt.fill_between(x, y, 3, where = (y > 0), facecolor='g', alpha=0.6)

plt.title("Sample Plot")
plt.show()

# %%
variable_name = 2 # @param {"type":"string","placeholder":"Enter Full Name please"}
Email = "Abrahem.Amar@e.braude.ac.il" # @param {"type":"string"}
variable_name = 1 # @param {"type":"slider","min":1,"max":4,"step":1}
Gender = "Male" # @param ["Male","FeMale"] {"allow-input":true}
#@title Date fields
date_input = '2025-11-02' #@param {type:"date"}

# %%
variable_name, Email, variable_name, Gender, date_input
# Out:
# (1, 'Abrahem.Amar@e.braude.ac.il', 1, 'Male', '2025-11-02')

# %%
#@title HTML
# %%html
<style>
body {
  background-color: #f2bcca;
}
</style>
<svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
   <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
   <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0;" />
   <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0;" />
</svg>
# Out:
# <style>
# body {
#   background-color: #f2bcca;
# }
# </style>
# <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#    <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0;" />
#    <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0;" />
# </svg>

# %%
with open("1.txt", "w") as fid:
  fid.write("hello")

# %%
with open('1.txt', 'r') as file:
    contents = file.read()
    print(contents)
# Out:
# hello

# %%
with open('example.txt', 'w') as file:
    file.write('This is some example text.')

# %%
import ipywidgets as widgets
from IPython.display import display
button = widgets.Button(description="Click Me!")
output = widgets.Output()

def on_button_clicked(b):
  # Display the message within the output widget.
  with output:
    with open('/content/1.txt', 'r') as file:
      contents = file.read()
      print(contents)

button.on_click(on_button_clicked)
display(button, output)
# Out:
# Button(description='Click Me!', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
slider = widgets.IntSlider(value=5, max=10)
display(slider)
# Out:
# IntSlider(value=5, max=10)

# %%
from typing import Text


w = widgets.Dropdown(
    options=['Addition', 'Multiplication', 'Subtraction', 'Division'],
    value='Addition',
    description='Task:',
)
txt1=widgets.Text()
txt1.value="1"
display(txt1)


def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        print("changed to %s" % change['new'])
    txt1.value=w.value


w.observe(on_change)


display(w)
# Out:
# Text(value='1')
# Dropdown(description='Task:', options=('Addition', 'Multiplication', 'Subtraction', 'Division'), value='Additi…
# changed to Multiplication
# changed to Subtraction
